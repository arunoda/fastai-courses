# %% [markdown]
# # Identifying Vehicles
#
# This is dataset I created after the lesson1 with 10 different types of vehicles. Let's see how we can train a model for that.

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
from fastai import *
from fastai.vision import *

# %%
dataset_url = "https://github.com/arunoda/fastai-courses/releases/download/fastai-vehicles-dataset/fastai-vehicles.tgz"

# %% [markdown]
# ## Loading Data
#
# Currently it's not possible to load data using `untar_data` for data stored in GitHub.<br/>
# So, I've to come up with the following utility function to support that.

# %%
import os
import subprocess

def exec(commands, cwd=None, show_output=False):
  FNULL = open(os.devnull, 'w')
  if show_output == True:
    cp = subprocess.run(commands, cwd=cwd, universal_newlines=True)
  else:
    cp = subprocess.run(commands, cwd=cwd, stdout=subprocess.PIPE, stderr=subprocess.STDOUT, universal_newlines=True)
  
  if cp.returncode != 0:
    raise Exception(cp.stdout)

def get_data(name, url):
  homedir = os.getenv('HOME')
  datadir = f'{homedir}/userdata'
  tmpdir = f'/tmp/{name}'
  tarfile = f'{tmpdir}/data.tgz'
  finaldir = f'{datadir}/{name}'

  if os.path.exists(finaldir):
    return Path(finaldir)

  exec(['rm', '-rf', tmpdir])
  exec(['mkdir', '-p', tmpdir])
  exec(['curl', '-L', url, '--output', tarfile], show_output=True)
  exec(['tar', 'xzf', tarfile], cwd=tmpdir)
  exec(['rm', tarfile])

  exec(['rm', '-rf', finaldir])
  exec(['mkdir', '-p', datadir])
  exec(['mv', tmpdir, datadir])
  
  return Path(finaldir)

# %%
path = get_data("fastai-vehicles", dataset_url); path
# Out:
# PosixPath('/home/arunoda/userdata/fastai-vehicles')

# %%
path.ls()
# Out:
# ['images']

# %%
path_img = path/'images'
fnames = get_image_files(path_img)
len(fnames)
# Out:
# 1169

# %%
fnames[:5]
# Out:
# [PosixPath('/home/arunoda/userdata/fastai-vehicles/images/ suzuki-wagonr-60.jpg'),
#  PosixPath('/home/arunoda/userdata/fastai-vehicles/images/ suzuki-wagonr-97.jpg'),
#  PosixPath('/home/arunoda/userdata/fastai-vehicles/images/audi-q2-67.jpg'),
#  PosixPath('/home/arunoda/userdata/fastai-vehicles/images/audi-a3-64.jpg'),
#  PosixPath('/home/arunoda/userdata/fastai-vehicles/images/ suzuki-wagonr-40.jpg')]

# %% [markdown]
# Okay. Now we've some idea of our dataset. Let's try to create a DataBunch from these images.

# %%
pattern = r' *([^/]+)-\d+.jpg$'
data = ImageDataBunch.from_name_re(path_img, fnames, pattern, a)
data.normalize(imagenet_stats)

# %%
print(len(data.classes))
data.classes
# Out:
# 10
# ['suzuki-wagonr',
#  'audi-q2',
#  'audi-a3',
#  'honda-crv',
#  'rangerover',
#  'suzuki-swift',
#  'defender',
#  'honda-civic',
#  'jeep-wrangler',
#  'honda-fit']

# %% [markdown]
# Let's see some random images from our dataset.

# %%
data.show_batch(3, (10, 10))

# %%
# This is a helper function which will help us later on
def find_lr(l):
    l.lr_find();
    l.recorder.plot();

# %% [markdown]
# ## Case1: use resnet34 for training
#
# Let's try to train a model with these data.

# %%
learn1 = ConvLearner(data, models.resnet34, metrics=error_rate)

# %%
learn1.fit_one_cycle(4)
# Out:
# Total time: 00:18
# epoch  train_loss  valid_loss  error_rate
# 1      2.189602    1.205166    0.409910    (00:04)
# 2      1.493517    0.697307    0.229730    (00:04)
# 3      1.112668    0.571896    0.189189    (00:04)
# 4      0.900561    0.565570    0.202703    (00:04)

# %%
learn1.save('vehicles-l1-freeze')

# %%
find_lr(learn1)
# Out:
# LR Finder complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn1.unfreeze()

# %%
learn1.fit_one_cycle(3, slice(1e-5, 1e-2))
# Out:
# Total time: 00:15
# epoch  train_loss  valid_loss  error_rate
# 1      0.575099    0.848083    0.198198    (00:05)
# 2      0.437049    0.448571    0.112613    (00:05)
# 3      0.334116    0.326844    0.108108    (00:05)

# %% [markdown]
# **Here, unfreeze results are pretty good.** <br/>

# %% [markdown]
# ## Inspect Result
#
# Here we have an error rate of 15%. Which is bit higher. (But not bad). <br/>
# Let's see what has happened to our model.

# %%
inspect = ClassificationInterpretation.from_learner(learn1)

# %%
inspect.plot_top_losses(9)

# %% [markdown]
# Based on above images, it seems like these are somewhat complex images.

# %%
interpret.plot_confusion_matrix()

# %%
interpret.most_confused(1)
# Out:
# [('jeep-wrangler', 'defender', 3),
#  ('suzuki-wagonr', 'suzuki-swift', 2),
#  ('suzuki-wagonr', 'defender', 2),
#  ('audi-q2', 'audi-a3', 2),
#  ('audi-a3', 'audi-q2', 2),
#  ('audi-a3', 'rangerover', 2),
#  ('suzuki-swift', 'rangerover', 2),
#  ('honda-fit', 'rangerover', 2),
#  ('honda-fit', 'honda-civic', 2)]

# %% [markdown]
# ## Case2: use resnet50

# %%
learn2 = ConvLearner(data, models.resnet50, metrics=error_rate)
learn2.fit_one_cycle(4)
# Out:
# Total time: 00:25
# epoch  train_loss  valid_loss  error_rate
# 1      1.690283    0.905783    0.333333    (00:06)
# 2      1.077251    0.640019    0.202703    (00:06)
# 3      0.770291    0.587176    0.175676    (00:06)
# 4      0.587581    0.560390    0.184685    (00:06)

# %%
find_lr(learn2)
# Out:
# LR Finder complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn2.unfreeze()
learn2.fit_one_cycle(3, slice(1e-5, 1e-3))
# Out:
# Total time: 00:22
# epoch  train_loss  valid_loss  error_rate
# 1      0.276876    0.442019    0.153153    (00:07)
# 2      0.236160    0.441781    0.135135    (00:07)
# 3      0.178739    0.389105    0.112613    (00:07)

# %% [markdown]
# **Notes**
#
# The improvement we got here is similar to what we've got with resnet34. <br/>
# So, changing the model doesn't improve the result significantly.

# %% [markdown]
# ##  Case3: Use square images
#
# Here we are using square images directly from the source.<br/>
# So, when we do a center crop, we don't lose the details of the image.<br/>
# Let's see how this model work.

# %%
dataset_url_sq = 'https://github.com/arunoda/fastai-courses/releases/download/fastai-vehicles-dataset/fastai-vehicles-square.tgz'
path_sq = get_data('fastai-vehicles-square', dataset_url_sq)

# %%
path_img_sq = path_sq/'images'
fnames_sq = get_image_files(path_img_sq)

# %%
pattern = r' *([^/]+)-\d+.jpg$'
data_sq = ImageDataBunch.from_name_re(path_img_sq, fnames_sq, pattern, ds_tfms=get_transforms(), size=224)
data_sq.normalize(imagenet_stats)

# %%
data_sq.show_batch(3, (6, 6))

# %%
learn3 = ConvLearner(data_sq, models.resnet34, metrics=error_rate)
learn3.fit_one_cycle(4)
# Out:
# Total time: 00:15
# epoch  train_loss  valid_loss  error_rate
# 1      2.247180    1.244447    0.443983    (00:04)
# 2      1.621232    0.824998    0.282158    (00:03)
# 3      1.261806    0.762728    0.278008    (00:03)
# 4      1.029972    0.712413    0.248963    (00:03)

# %%
find_lr(learn3)
# Out:
# LR Finder complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn3.unfreeze()
learn3.fit_one_cycle(3, slice(1e-6, 1e-3))
# Out:
# Total time: 00:14
# epoch  train_loss  valid_loss  error_rate
# 1      0.647167    0.568838    0.170124    (00:04)
# 2      0.542293    0.504406    0.153527    (00:04)
# 3      0.451728    0.473402    0.145228    (00:04)

# %%
inspect = ClassificationInterpretation.from_learner(learn3)

# %%
inspect.plot_top_losses(9)

# %%
inspect.plot_confusion_matrix()

# %%
inspect.most_confused(1)
# Out:
# [('honda-civic', 'honda-crv', 4),
#  ('audi-q2', 'honda-crv', 2),
#  ('audi-q2', 'rangerover', 2),
#  ('audi-a3', 'audi-q2', 2),
#  ('audi-a3', 'honda-crv', 2),
#  ('audi-a3', 'rangerover', 2),
#  ('honda-crv', 'honda-fit', 2),
#  ('rangerover', 'honda-fit', 2),
#  ('suzuki-swift', 'audi-a3', 2),
#  ('honda-fit', 'honda-crv', 2)]

# %% [markdown]
# **Notes**<br/>
#
# Even with the square images, result is still the same.<br/>
# May be it's worst than before.<br/>
# So, our original **resnet34** version is still better.

# %% [markdown]
# ## Case4: More Data Augmentation
#
# Let's try to use the original dataset with the resnet34 but with more data augmentation methods.<br/>
# By doing that, we've introduced more version of images to train.

# %%
path_crops = get_data('fastai-vehicles-crops', 'https://github.com/arunoda/fastai-courses/releases/download/fastai-vehicles-dataset/fastai-vehicles-crops.tgz')

# %%
img_path_crops = path_crops/'images'

# %%
fnames_crops = get_image_files(img_path_crops)

# %%
fnames_crops[:5]
# Out:
# [PosixPath('/home/arunoda/userdata/fastai-vehicles-crops/images/suzuki-swift-east-49.jpg'),
#  PosixPath('/home/arunoda/userdata/fastai-vehicles-crops/images/audi-a3-west-74.jpg'),
#  PosixPath('/home/arunoda/userdata/fastai-vehicles-crops/images/defender-center-38.jpg'),
#  PosixPath('/home/arunoda/userdata/fastai-vehicles-crops/images/rangerover-west-33.jpg'),
#  PosixPath('/home/arunoda/userdata/fastai-vehicles-crops/images/jeep-wrangler-west-118.jpg')]

# %%
pattern_crop = r'( *[^/]+)-[east|west|center]+-\d+.jpg$'

# %%
data_crops = ImageDataBunch.from_name_re(img_path_crops, fnames_crops, pattern_crop, ds_tfms=get_transforms(), size=224)

# %%
data_crops.normalize(imagenet_stats)

# %%
data_crops.show_batch(3, (10, 10))

# %%
learn4 = ConvLearner(data_crops, models.resnet34, metrics=error_rate)

# %%
learn4.fit_one_cycle(4)
# Out:
# Total time: 00:33
# epoch  train_loss  valid_loss  error_rate
# 1      1.538743    0.631324    0.210027    (00:08)
# 2      0.880741    0.336131    0.111111    (00:08)
# 3      0.555413    0.254354    0.079946    (00:08)
# 4      0.388959    0.245521    0.077236    (00:08)

# %%
learn4.save('vehicles-l4-freeze')

# %%
find_lr(learn4)
# Out:
# LR Finder complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn4.unfreeze()

# %%
learn4.fit_one_cycle(1, 1e-6)
# Out:
# Total time: 00:16
# epoch  train_loss  valid_loss  error_rate
# 1      0.262079    0.234340    0.071816    (00:08)
# 2      0.279357    0.239436    0.071816    (00:08)

# %%
inspect4 = ClassificationInterpretation.from_learner(learn4)

# %%
inspect4.plot_top_losses(9)

# %%
inspect4.most_confused(1)
# Out:
# [('defender', 'jeep-wrangler', 6),
#  ('audi-a3', 'audi-q2', 4),
#  ('suzuki-swift', 'audi-a3', 2),
#  ('suzuki-swift', 'rangerover', 2),
#  ('audi-a3', 'rangerover', 2),
#  ('audi-a3', 'honda-fit', 2),
#  ('rangerover', 'audi-a3', 2),
#  ('rangerover', 'defender', 2),
#  ('audi-q2', 'audi-a3', 2),
#  ('audi-q2', 'rangerover', 2),
#  ('honda-crv', 'honda-civic', 2)]

# %% [markdown]
# **Notes**
#
# This is a really good improvement. By providing more data on different parts of the image, we improve the accuracy of our model.

# %% [markdown]
# ## Case5: More data augmentation with resnet50
#
# Same as above, but with resnet50.

# %%
learn5 = ConvLearner(data_crops, models.resnet50, metrics=error_rate)

# %%
learn5.fit_one_cycle(4)
# Out:
# Total time: 00:57
# epoch  train_loss  valid_loss  error_rate
# 1      1.082083    0.399406    0.134146    (00:17)
# 2      0.600281    0.229177    0.069106    (00:13)
# 3      0.359158    0.130960    0.036585    (00:13)
# 4      0.225878    0.121577    0.028455    (00:13)

# %%
learn5.save('vehicles-l5-freeze')

# %%
find_lr(learn5)
# Out:
# LR Finder complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn5.unfreeze()

# %%
learn5.fit_one_cycle(2, 1e-6)
# Out:
# Total time: 00:34
# epoch  train_loss  valid_loss  error_rate
# 1      0.140499    0.117208    0.032520    (00:17)
# 2      0.142560    0.118126    0.032520    (00:16)

# %%
## resnet50 is better with freezed.
learn5.load('vehicles-l5-freeze')

# %% [markdown]
# ------------------
# **Final Verdict**
#
# resnet50 freezed with different crops of vehicles gives us a better model.
